# %%
# !conda install -c conda-forge opencv

# %%
import os
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras import layers, Model
from sklearn.model_selection import train_test_split

from keras.layers import Conv2D, PReLU, BatchNormalization,Flatten
from keras.layers import UpSampling2D, LeakyReLU, Dense, Input, add
from tqdm import tqdm #progess bar
from keras.applications.vgg19 import VGG19
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 import os
# ----> 2 import cv2 as cv
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# #preparing h5py for vgg

# import sys
# !conda install --yes --prefix {sys.prefix} h5py

# %%
train_dir = "H:/python3/pythonProject/venv/AIP_Project/Gan_SuperRes/Gan_SuperRes/train_dir"

# for img in os.listdir(train_dir +"/original_images/mirflickr25k/mirflickr"):
#     img_array = cv.imread(train_dir + "/original_images/mirflickr25k/mirflickr/" + img)

#     img_array = cv.resize(img_array, (256,256))
#     lr_img_array = cv.GaussianBlur(img_array,(5,5),0)
#     lr_img_array = cv.resize(img_array,(64,64))
#     cv.imwrite(train_dir+"/hr_images/"+img,img_array)
#     cv.imwrite(train_dir+"/lr_images/"+img,lr_img_array)

# %%
#Generator

def res_block(ip):
    res_model = Conv2D(64,(5,5), padding="same")(ip)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    res_model = Conv2D(64, (3,3), padding = "same")(res_model)
    res_model = BatchNormalization(momentum = 0.5)(res_model)
    res_model = PReLU(shared_axes = [1,2])(res_model)

    res_model = Conv2D(64, (3,3), padding = "same")(res_model)
    res_model = BatchNormalization(momentum = 0.5)(res_model)

    return add([ip, res_model])

def upscale_block(ip):

    up_model = Conv2D(256, (3,3), padding="same")(ip)
    up_model = PReLU(shared_axes=[1,2])(up_model)
    up_model = Conv2D(256, (3,3), padding="same")(up_model)
    up_model = BatchNormalization(momentum=0.5)(up_model)
    up_model = UpSampling2D(size=2)(up_model)
    up_model = PReLU(shared_axes=[1,2])(up_model)
    return up_model

def create_gen(gen_ip, num_res_block):
    layers = Conv2D(64, (9,9),padding = "same")(gen_ip)
    layers = PReLU(shared_axes=[1,2])(layers)
    layers = Conv2D(64, (5,5),padding = "same")(layers)
    layers = PReLU(shared_axes=[1,2])(layers)


    temp = layers

    for i in range(num_res_block):
        layers = res_block(layers)

    layers = Conv2D(64, (3,3), padding="same")(layers)
    layers = BatchNormalization(momentum=0.5)(layers)
    layers = add([layers,temp])

    layers = upscale_block(layers)
    layers = upscale_block(layers)

    op = Conv2D(3, (9,9), padding="same")(layers)

    return Model(inputs=gen_ip, outputs=op)

# %%
# Discriminator

def discriminator_block(ip, filters, strides=1, bn=True):
    disc_model = Conv2D(filters, (3,3) ,strides = strides, padding="same")(ip)

    if bn:
        disc_model = BatchNormalization( momentum=0.8)(disc_model)

    disc_model = LeakyReLU( alpha=0.3)(disc_model)

    return disc_model

def create_disc(disc_ip):
    df = 40

    d1 = discriminator_block(disc_ip, df , bn = False)
    d2 = discriminator_block(d1, df, strides=2)
    d3 = discriminator_block(d2, df*2)
    d4 = discriminator_block(d3, df*2, strides = 2)
    d5 = discriminator_block(d4, df*4)
    d6 = discriminator_block(d5, df*4, strides=2)
    d7 = discriminator_block(d6, df*8)
    d8 = discriminator_block(d7, df*8, strides=2)

    d8_5 = Flatten()(d8)
    d9 = Dense(df*16)(d8_5)
    d10 = LeakyReLU(alpha=0.3)(d9)
    validity = Dense(1, activation='sigmoid')(d10)

    return Model(disc_ip, validity)

# %%
# Combination

def build_vgg(hr_shape):

    vgg = VGG19(weights="imagenet",include_top=False, input_shape=hr_shape)

    return Model(inputs=vgg.inputs, outputs=vgg.layers[10].output)

def create_comb(gen_model, disc_model, vgg, lr_ip, hr_ip):
    gen_img = gen_model(lr_ip)
    gen_features = vgg(gen_img)

    disc_model.trainable = False
    validity = disc_model(gen_img)

    return Model(inputs=[lr_ip, hr_ip], outputs=[validity, gen_features])

# %%
# Load data

n=25000
lr_list = os.listdir(train_dir + "/lr_images")[:n]

# lr_images = []
# for img in lr_list:
#     img_lr = cv2.imread("lr_images/"+img)
#     img_lr = cv2.cvtColor(img_lr, cv2.COLOR_BGR2RGB)
#     lr_images.append(img_lr)
lr_image_urls = []
for url in lr_list:
    lr_image_urls.append(str("lr_images/"+url))

hr_list = os.listdir(train_dir + "/hr_images")[:n]

# hr_images = []
# for img in hr_list:
#     img_hr = cv2.imread("hr_images/"+img)
#     img_hr = cv2.cvtColor(img_hr, cv2.COLOR_BGR2RGB)
#     hr_images.append(img_hr)
hr_image_urls = []
for url in lr_list:
    hr_image_urls.append(str("hr_images/"+url))

# lr_images = np.array(lr_images)
# hr_images = np.array(hr_images)

#Plot random lr and hr image
# import random
# import numpy as np
# image_number = random.randint(0,len(lr_images)-1)
# plt.figure(figsize=(12,6))
# plt.subplot(121)
# plt.imshow(np.reshape(lr_images[image_number],(32,32,3)))
# plt.subplot(122)
# plt.imshow(np.reshape(hr_images[image_number],(128,128,3)))
# plt.show()

# lr_images = lr_images/255
# hr_images = hr_images/255

lr_train, lr_test, hr_train, hr_test = train_test_split(lr_image_urls, hr_image_urls,test_size=0.01,random_state=True)

# hr_shape = (hr_train.shape[1], hr_train.shape[2], hr_train.shape[3])
# lr_shape = (lr_train.shape[1], lr_train.shape[2], lr_train.shape[3])

hr_shape = (256,256,3)
lr_shape = (64,64,3)

lr_ip = Input(shape=lr_shape)
hr_ip = Input(shape=hr_shape)

# %%
# !conda remove --force h5py
import sys
# !conda install --yes --prefix {sys.prefix} h5py
# Out:
# PackagesNotFoundError: The following packages are missing from the target environment:
#   - h5py
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Admin\miniconda3\envs\tensorflow
#
#   added / updated specs:
#     - h5py
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     hdf5-1.10.6                |       h1756f20_1         7.9 MB
#     ------------------------------------------------------------
#                                            Total:         7.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   h5py               pkgs/main/win-64::h5py-3.7.0-py39h3de5c98_0 None
#
# The following packages will be DOWNGRADED:
#
#   hdf5                                    1.12.1-h1756f20_2 --> 1.10.6-h1756f20_1 None
#
#
#
# Downloading and Extracting Packages
#
# hdf5-1.10.6          | 7.9 MB    |            |   0%
# hdf5-1.10.6          | 7.9 MB    |            |   0%
# hdf5-1.10.6          | 7.9 MB    | 2          |   2%
# hdf5-1.10.6          | 7.9 MB    | 5          |   5%
# hdf5-1.10.6          | 7.9 MB    | 6          |   7%
# hdf5-1.10.6          | 7.9 MB    | 8          |   8%
# hdf5-1.10.6          | 7.9 MB    | #          |  10%
# hdf5-1.10.6          | 7.9 MB    | #2         |  12%
# hdf5-1.10.6          | 7.9 MB    | #5         |  15%
# hdf5-1.10.6          | 7.9 MB    | #8         |  19%
# hdf5-1.10.6          | 7.9 MB    | ##1        |  21%
# hdf5-1.10.6          | 7.9 MB    | ##3        |  23%
# hdf5-1.10.6          | 7.9 MB    | ##5        |  25%
# hdf5-1.10.6          | 7.9 MB    | ##7        |  27%
# hdf5-1.10.6          | 7.9 MB    | ###3       |  33%
# hdf5-1.10.6          | 7.9 MB    | ###4       |  34%
# hdf5-1.10.6          | 7.9 MB    | ###7       |  38%
# hdf5-1.10.6          | 7.9 MB    | ###9       |  40%
# hdf5-1.10.6          | 7.9 MB    | ####       |  41%
# hdf5-1.10.6          | 7.9 MB    | ####7      |  47%
# hdf5-1.10.6          | 7.9 MB    | ####8      |  48%
# hdf5-1.10.6          | 7.9 MB    | ####9      |  50%
# hdf5-1.10.6          | 7.9 MB    | #####      |  51%
# hdf5-1.10.6          | 7.9 MB    | #####1     |  51%
# hdf5-1.10.6          | 7.9 MB    | #####1     |  52%
# hdf5-1.10.6          | 7.9 MB    | #####2     |  53%
# hdf5-1.10.6          | 7.9 MB    | #####2     |  53%
# hdf5-1.10.6          | 7.9 MB    | #####4     |  54%
# hdf5-1.10.6          | 7.9 MB    | #####4     |  55%
# hdf5-1.10.6          | 7.9 MB    | #####5     |  56%
# hdf5-1.10.6          | 7.9 MB    | #####6     |  56%
# hdf5-1.10.6          | 7.9 MB    | #####6     |  57%
# hdf5-1.10.6          | 7.9 MB    | #####7     |  57%
# hdf5-1.10.6          | 7.9 MB    | #####7     |  58%
# hdf5-1.10.6          | 7.9 MB    | #####8     |  58%
# hdf5-1.10.6          | 7.9 MB    | #####8     |  58%
# hdf5-1.10.6          | 7.9 MB    | #####9     |  59%
# hdf5-1.10.6          | 7.9 MB    | #####9     |  60%
# hdf5-1.10.6          | 7.9 MB    | ######     |  60%
# hdf5-1.10.6          | 7.9 MB    | ######     |  61%
# hdf5-1.10.6          | 7.9 MB    | ######1    |  61%
# hdf5-1.10.6          | 7.9 MB    | ######1    |  62%
# hdf5-1.10.6          | 7.9 MB    | ######2    |  63%
# hdf5-1.10.6          | 7.9 MB    | ######3    |  63%
# hdf5-1.10.6          | 7.9 MB    | ######3    |  64%
# hdf5-1.10.6          | 7.9 MB    | ######5    |  66%
# hdf5-1.10.6          | 7.9 MB    | ######6    |  66%
# hdf5-1.10.6          | 7.9 MB    | ######6    |  67%
# hdf5-1.10.6          | 7.9 MB    | ######7    |  67%
# hdf5-1.10.6          | 7.9 MB    | ######7    |  68%
# hdf5-1.10.6          | 7.9 MB    | ######9    |  69%
# hdf5-1.10.6          | 7.9 MB    | ######9    |  69%
# hdf5-1.10.6          | 7.9 MB    | #######    |  70%
# hdf5-1.10.6          | 7.9 MB    | #######    |  71%
# hdf5-1.10.6          | 7.9 MB    | #######1   |  72%
# hdf5-1.10.6          | 7.9 MB    | #######2   |  72%
# hdf5-1.10.6          | 7.9 MB    | #######2   |  73%
# hdf5-1.10.6          | 7.9 MB    | #######3   |  74%
# hdf5-1.10.6          | 7.9 MB    | #######4   |  74%
# hdf5-1.10.6          | 7.9 MB    | #######5   |  75%
# hdf5-1.10.6          | 7.9 MB    | #######6   |  76%
# hdf5-1.10.6          | 7.9 MB    | #######7   |  77%
# hdf5-1.10.6          | 7.9 MB    | #######8   |  78%
# hdf5-1.10.6          | 7.9 MB    | #######9   |  79%
# hdf5-1.10.6          | 7.9 MB    | ########   |  80%
# hdf5-1.10.6          | 7.9 MB    | ########1  |  81%
# hdf5-1.10.6          | 7.9 MB    | ########2  |  83%
# hdf5-1.10.6          | 7.9 MB    | ########4  |  84%
# hdf5-1.10.6          | 7.9 MB    | ########5  |  86%
# hdf5-1.10.6          | 7.9 MB    | ########7  |  88%
# hdf5-1.10.6          | 7.9 MB    | ########9  |  90%
# hdf5-1.10.6          | 7.9 MB    | #########1 |  91%
# hdf5-1.10.6          | 7.9 MB    | #########2 |  93%
# hdf5-1.10.6          | 7.9 MB    | #########4 |  95%
# hdf5-1.10.6          | 7.9 MB    | #########6 |  96%
# hdf5-1.10.6          | 7.9 MB    | #########7 |  98%
# hdf5-1.10.6          | 7.9 MB    | #########8 |  99%
# hdf5-1.10.6          | 7.9 MB    | #########9 | 100%
# hdf5-1.10.6          | 7.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Retrieving notices: ...working... done

# %%
import h5py
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 import h5py
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:33, in <module>
#      30     else:
#      31         raise
# ---> 33 from . import version
#      35 if version.hdf5_version_tuple != version.hdf5_built_version_tuple:
#      36     _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
#      37            "this may cause problems").format(
#      38             '{0}.{1}.{2}'.format(*version.hdf5_version_tuple),
#      39             '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)
#      40     ))
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\h5py\version.py:15, in <module>
#      10 """
#      11     Versioning module for h5py.
#      12 """
#      14 from collections import namedtuple
# ---> 15 from . import h5 as _h5
#      16 import sys
#      17 import numpy
#
# File h5py\h5.pyx:1, in init h5py.h5()
#
# ImportError: DLL load failed while importing defs: The specified procedure could not be found.

# %%
# Model

generator = create_gen(lr_ip, num_res_block=20)
generator.summary()

discriminator = create_disc(hr_ip)
discriminator.compile(loss="binary_crossentropy",optimizer="adam",metrics=['accuracy'])
discriminator.summary()

vgg = build_vgg((256,256,3))
print(vgg.summary())
vgg.trainable = False

gan_model = create_comb(generator,discriminator,vgg,lr_ip,hr_ip)
gan_model.load_weights()


gan_model.compile(loss=["binary_crossentropy","mse"], loss_weights=[1e-3,1],optimizer="adam")
gan_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  conv2d_76 (Conv2D)             (None, 64, 64, 64)   15616       ['input_1[0][0]']
#
#  p_re_lu_26 (PReLU)             (None, 64, 64, 64)   64          ['conv2d_76[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 64, 64, 64)   102464      ['p_re_lu_26[0][0]']
#
#  p_re_lu_27 (PReLU)             (None, 64, 64, 64)   64          ['conv2d_77[0][0]']
#
#  conv2d_78 (Conv2D)             (None, 64, 64, 64)   102464      ['p_re_lu_27[0][0]']
#
#  batch_normalization_70 (BatchN  (None, 64, 64, 64)  256         ['conv2d_78[0][0]']
#  ormalization)
#
#  conv2d_79 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_70[0][0]']
#
#  batch_normalization_71 (BatchN  (None, 64, 64, 64)  256         ['conv2d_79[0][0]']
#  ormalization)
#
#  p_re_lu_28 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_71[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_28[0][0]']
#
#  batch_normalization_72 (BatchN  (None, 64, 64, 64)  256         ['conv2d_80[0][0]']
#  ormalization)
#
#  add_21 (Add)                   (None, 64, 64, 64)   0           ['p_re_lu_27[0][0]',
#                                                                   'batch_normalization_72[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 64, 64, 64)   102464      ['add_21[0][0]']
#
#  batch_normalization_73 (BatchN  (None, 64, 64, 64)  256         ['conv2d_81[0][0]']
#  ormalization)
#
#  conv2d_82 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_73[0][0]']
#
#  batch_normalization_74 (BatchN  (None, 64, 64, 64)  256         ['conv2d_82[0][0]']
#  ormalization)
#
#  p_re_lu_29 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_74[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_29[0][0]']
#
#  batch_normalization_75 (BatchN  (None, 64, 64, 64)  256         ['conv2d_83[0][0]']
#  ormalization)
#
#  add_22 (Add)                   (None, 64, 64, 64)   0           ['add_21[0][0]',
#                                                                   'batch_normalization_75[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 64, 64, 64)   102464      ['add_22[0][0]']
#
#  batch_normalization_76 (BatchN  (None, 64, 64, 64)  256         ['conv2d_84[0][0]']
#  ormalization)
#
#  conv2d_85 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_76[0][0]']
#
#  batch_normalization_77 (BatchN  (None, 64, 64, 64)  256         ['conv2d_85[0][0]']
#  ormalization)
#
#  p_re_lu_30 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_77[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_30[0][0]']
#
#  batch_normalization_78 (BatchN  (None, 64, 64, 64)  256         ['conv2d_86[0][0]']
#  ormalization)
#
#  add_23 (Add)                   (None, 64, 64, 64)   0           ['add_22[0][0]',
#                                                                   'batch_normalization_78[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 64, 64, 64)   102464      ['add_23[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 64, 64, 64)  256         ['conv2d_87[0][0]']
#  ormalization)
#
#  conv2d_88 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_79[0][0]']
#
#  batch_normalization_80 (BatchN  (None, 64, 64, 64)  256         ['conv2d_88[0][0]']
#  ormalization)
#  p_re_lu_31 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_80[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_31[0][0]']
#
#  batch_normalization_81 (BatchN  (None, 64, 64, 64)  256         ['conv2d_89[0][0]']
#  ormalization)
#
#  add_24 (Add)                   (None, 64, 64, 64)   0           ['add_23[0][0]',
#                                                                   'batch_normalization_81[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 64, 64, 64)   102464      ['add_24[0][0]']
#
#  batch_normalization_82 (BatchN  (None, 64, 64, 64)  256         ['conv2d_90[0][0]']
#  ormalization)
#
#  conv2d_91 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_82[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 64, 64, 64)  256         ['conv2d_91[0][0]']
#  ormalization)
#
#  p_re_lu_32 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_83[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_32[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 64, 64, 64)  256         ['conv2d_92[0][0]']
#  ormalization)
#
#  add_25 (Add)                   (None, 64, 64, 64)   0           ['add_24[0][0]',
#                                                                   'batch_normalization_84[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 64, 64, 64)   102464      ['add_25[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 64, 64, 64)  256         ['conv2d_93[0][0]']
#  ormalization)
#
#  conv2d_94 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_85[0][0]']
#
#  batch_normalization_86 (BatchN  (None, 64, 64, 64)  256         ['conv2d_94[0][0]']
#  ormalization)
#
#  p_re_lu_33 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_86[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_33[0][0]']
#
#  batch_normalization_87 (BatchN  (None, 64, 64, 64)  256         ['conv2d_95[0][0]']
#  ormalization)
#
#  add_26 (Add)                   (None, 64, 64, 64)   0           ['add_25[0][0]',
#                                                                   'batch_normalization_87[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 64, 64, 64)   102464      ['add_26[0][0]']
#
#  batch_normalization_88 (BatchN  (None, 64, 64, 64)  256         ['conv2d_96[0][0]']
#  ormalization)
#
#  conv2d_97 (Conv2D)             (None, 64, 64, 64)   36928       ['batch_normalization_88[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 64, 64, 64)  256         ['conv2d_97[0][0]']
#  ormalization)
#
#  p_re_lu_34 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_89[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 64, 64, 64)   36928       ['p_re_lu_34[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 64, 64, 64)  256         ['conv2d_98[0][0]']
#  ormalization)
#
#  add_27 (Add)                   (None, 64, 64, 64)   0           ['add_26[0][0]',
#                                                                   'batch_normalization_90[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 64, 64, 64)   102464      ['add_27[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 64, 64, 64)  256         ['conv2d_99[0][0]']
#  ormalization)
#
#  conv2d_100 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_91[0][0]']
#
#  batch_normalization_92 (BatchN  (None, 64, 64, 64)  256         ['conv2d_100[0][0]']
#  ormalization)
#
#  p_re_lu_35 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_92[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_35[0][0]']
#
#  batch_normalization_93 (BatchN  (None, 64, 64, 64)  256         ['conv2d_101[0][0]']
#  ormalization)
#
#  add_28 (Add)                   (None, 64, 64, 64)   0           ['add_27[0][0]',
#                                                                   'batch_normalization_93[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 64, 64, 64)   102464      ['add_28[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 64, 64, 64)  256         ['conv2d_102[0][0]']
#  ormalization)
#
#  conv2d_103 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_94[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 64, 64, 64)  256         ['conv2d_103[0][0]']
#  ormalization)
#
#  p_re_lu_36 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_95[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_36[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 64, 64, 64)  256         ['conv2d_104[0][0]']
#  ormalization)
#
#  add_29 (Add)                   (None, 64, 64, 64)   0           ['add_28[0][0]',
#                                                                   'batch_normalization_96[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 64, 64, 64)   102464      ['add_29[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 64, 64, 64)  256         ['conv2d_105[0][0]']
#  ormalization)
#
#  conv2d_106 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 64, 64, 64)  256         ['conv2d_106[0][0]']
#  ormalization)
#
#  p_re_lu_37 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_98[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_37[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 64, 64, 64)  256         ['conv2d_107[0][0]']
#  ormalization)
#
#  add_30 (Add)                   (None, 64, 64, 64)   0           ['add_29[0][0]',
#                                                                   'batch_normalization_99[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 64, 64, 64)   102464      ['add_30[0][0]']
#
#  batch_normalization_100 (Batch  (None, 64, 64, 64)  256         ['conv2d_108[0][0]']
#  Normalization)
#
#  conv2d_109 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_100[0][0]']
#
#  batch_normalization_101 (Batch  (None, 64, 64, 64)  256         ['conv2d_109[0][0]']
#  Normalization)
#
#  p_re_lu_38 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_101[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_38[0][0]']
#
#  batch_normalization_102 (Batch  (None, 64, 64, 64)  256         ['conv2d_110[0][0]']
#  Normalization)
#
#  add_31 (Add)                   (None, 64, 64, 64)   0           ['add_30[0][0]',
#                                                                   'batch_normalization_102[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 64, 64, 64)   102464      ['add_31[0][0]']
#
#  batch_normalization_103 (Batch  (None, 64, 64, 64)  256         ['conv2d_111[0][0]']
#  Normalization)
#
#  conv2d_112 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_103[0][0]']
#
#  batch_normalization_104 (Batch  (None, 64, 64, 64)  256         ['conv2d_112[0][0]']
#  Normalization)
#
#  p_re_lu_39 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_104[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_39[0][0]']
#
#  batch_normalization_105 (Batch  (None, 64, 64, 64)  256         ['conv2d_113[0][0]']
#  Normalization)
#
#  add_32 (Add)                   (None, 64, 64, 64)   0           ['add_31[0][0]',
#                                                                   'batch_normalization_105[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 64, 64, 64)   102464      ['add_32[0][0]']
#
#  batch_normalization_106 (Batch  (None, 64, 64, 64)  256         ['conv2d_114[0][0]']
#  Normalization)
#
#  conv2d_115 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_106[0][0]']
#
#  batch_normalization_107 (Batch  (None, 64, 64, 64)  256         ['conv2d_115[0][0]']
#  Normalization)
#
#  p_re_lu_40 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_107[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_40[0][0]']
#
#  batch_normalization_108 (Batch  (None, 64, 64, 64)  256         ['conv2d_116[0][0]']
#  Normalization)
#
#  add_33 (Add)                   (None, 64, 64, 64)   0           ['add_32[0][0]',
#                                                                   'batch_normalization_108[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 64, 64, 64)   102464      ['add_33[0][0]']
#
#  batch_normalization_109 (Batch  (None, 64, 64, 64)  256         ['conv2d_117[0][0]']
#  Normalization)
#
#  conv2d_118 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_109[0][0]']
#
#  batch_normalization_110 (Batch  (None, 64, 64, 64)  256         ['conv2d_118[0][0]']
#  Normalization)
#
#  p_re_lu_41 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_110[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_41[0][0]']
#
#  batch_normalization_111 (Batch  (None, 64, 64, 64)  256         ['conv2d_119[0][0]']
#  Normalization)
#
#  add_34 (Add)                   (None, 64, 64, 64)   0           ['add_33[0][0]',
#                                                                   'batch_normalization_111[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 64, 64, 64)   102464      ['add_34[0][0]']
#
#  batch_normalization_112 (Batch  (None, 64, 64, 64)  256         ['conv2d_120[0][0]']
#  Normalization)
#
#  conv2d_121 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_112[0][0]']
#
#  batch_normalization_113 (Batch  (None, 64, 64, 64)  256         ['conv2d_121[0][0]']
#  Normalization)
#
#  p_re_lu_42 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_113[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_42[0][0]']
#
#  batch_normalization_114 (Batch  (None, 64, 64, 64)  256         ['conv2d_122[0][0]']
#  Normalization)
#
#  add_35 (Add)                   (None, 64, 64, 64)   0           ['add_34[0][0]',
#                                                                   'batch_normalization_114[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 64, 64, 64)   102464      ['add_35[0][0]']
#
#  batch_normalization_115 (Batch  (None, 64, 64, 64)  256         ['conv2d_123[0][0]']
#  Normalization)
#
#  conv2d_124 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_115[0][0]']
#
#  batch_normalization_116 (Batch  (None, 64, 64, 64)  256         ['conv2d_124[0][0]']
#  Normalization)
#
#  p_re_lu_43 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_116[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_43[0][0]']
#
#  batch_normalization_117 (Batch  (None, 64, 64, 64)  256         ['conv2d_125[0][0]']
#  Normalization)
#
#  add_36 (Add)                   (None, 64, 64, 64)   0           ['add_35[0][0]',
#                                                                   'batch_normalization_117[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 64, 64, 64)   102464      ['add_36[0][0]']
#
#  batch_normalization_118 (Batch  (None, 64, 64, 64)  256         ['conv2d_126[0][0]']
#  Normalization)
#
#  conv2d_127 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_118[0][0]']
#
#  batch_normalization_119 (Batch  (None, 64, 64, 64)  256         ['conv2d_127[0][0]']
#  Normalization)
#
#  p_re_lu_44 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_119[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_44[0][0]']
#
#  batch_normalization_120 (Batch  (None, 64, 64, 64)  256         ['conv2d_128[0][0]']
#  Normalization)
#
#  add_37 (Add)                   (None, 64, 64, 64)   0           ['add_36[0][0]',
#                                                                   'batch_normalization_120[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 64, 64, 64)   102464      ['add_37[0][0]']
#
#  batch_normalization_121 (Batch  (None, 64, 64, 64)  256         ['conv2d_129[0][0]']
#  Normalization)
#
#  conv2d_130 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 64, 64, 64)  256         ['conv2d_130[0][0]']
#  Normalization)
#
#  p_re_lu_45 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_122[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_45[0][0]']
#
#  batch_normalization_123 (Batch  (None, 64, 64, 64)  256         ['conv2d_131[0][0]']
#  Normalization)
#
#  add_38 (Add)                   (None, 64, 64, 64)   0           ['add_37[0][0]',
#                                                                   'batch_normalization_123[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 64, 64, 64)   102464      ['add_38[0][0]']
#
#  batch_normalization_124 (Batch  (None, 64, 64, 64)  256         ['conv2d_132[0][0]']
#  Normalization)
#
#  conv2d_133 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_124[0][0]']
#
#  batch_normalization_125 (Batch  (None, 64, 64, 64)  256         ['conv2d_133[0][0]']
#  Normalization)
#
#  p_re_lu_46 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_125[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_46[0][0]']
#
#  batch_normalization_126 (Batch  (None, 64, 64, 64)  256         ['conv2d_134[0][0]']
#  Normalization)
#
#  add_39 (Add)                   (None, 64, 64, 64)   0           ['add_38[0][0]',
#                                                                   'batch_normalization_126[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 64, 64, 64)   102464      ['add_39[0][0]']
#
#  batch_normalization_127 (Batch  (None, 64, 64, 64)  256         ['conv2d_135[0][0]']
#  Normalization)
#
#  conv2d_136 (Conv2D)            (None, 64, 64, 64)   36928       ['batch_normalization_127[0][0]']
#
#  batch_normalization_128 (Batch  (None, 64, 64, 64)  256         ['conv2d_136[0][0]']
#  Normalization)
#
#  p_re_lu_47 (PReLU)             (None, 64, 64, 64)   64          ['batch_normalization_128[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 64, 64, 64)   36928       ['p_re_lu_47[0][0]']
#
#  batch_normalization_129 (Batch  (None, 64, 64, 64)  256         ['conv2d_137[0][0]']
#  Normalization)
#
#  add_40 (Add)                   (None, 64, 64, 64)   0           ['add_39[0][0]',
#                                                                   'batch_normalization_129[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 64, 64, 64)   36928       ['add_40[0][0]']
#  batch_normalization_130 (Batch  (None, 64, 64, 64)  256         ['conv2d_138[0][0]']
#  Normalization)
#
#  add_41 (Add)                   (None, 64, 64, 64)   0           ['batch_normalization_130[0][0]',
#                                                                   'p_re_lu_27[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 64, 64, 256)  147712      ['add_41[0][0]']
#
#  p_re_lu_48 (PReLU)             (None, 64, 64, 256)  256         ['conv2d_139[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 64, 64, 256)  590080      ['p_re_lu_48[0][0]']
#
#  batch_normalization_131 (Batch  (None, 64, 64, 256)  1024       ['conv2d_140[0][0]']
#  Normalization)
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 25  0          ['batch_normalization_131[0][0]']
#                                 6)
#
#  p_re_lu_49 (PReLU)             (None, 128, 128, 25  256         ['up_sampling2d_2[0][0]']
#                                 6)
#
#  conv2d_141 (Conv2D)            (None, 128, 128, 25  590080      ['p_re_lu_49[0][0]']
#                                 6)
#
#  p_re_lu_50 (PReLU)             (None, 128, 128, 25  256         ['conv2d_141[0][0]']
#                                 6)
#
#  conv2d_142 (Conv2D)            (None, 128, 128, 25  590080      ['p_re_lu_50[0][0]']
#                                 6)
#
#  batch_normalization_132 (Batch  (None, 128, 128, 25  1024       ['conv2d_142[0][0]']
#  Normalization)                 6)
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 25  0          ['batch_normalization_132[0][0]']
#                                 6)
#
#  p_re_lu_51 (PReLU)             (None, 256, 256, 25  256         ['up_sampling2d_3[0][0]']
#                                 6)
#
#  conv2d_143 (Conv2D)            (None, 256, 256, 3)  62211       ['p_re_lu_51[0][0]']
#
# ==================================================================================================
# Total params: 5,681,667
# Trainable params: 5,672,835
# Non-trainable params: 8,832
# __________________________________________________________________________________________________
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_144 (Conv2D)         (None, 256, 256, 40)      1120
#
#  leaky_re_lu_9 (LeakyReLU)   (None, 256, 256, 40)      0
#
#  conv2d_145 (Conv2D)         (None, 128, 128, 40)      14440
#
#  batch_normalization_133 (Ba  (None, 128, 128, 40)     160
#  tchNormalization)
#
#  leaky_re_lu_10 (LeakyReLU)  (None, 128, 128, 40)      0
#
#  conv2d_146 (Conv2D)         (None, 128, 128, 80)      28880
#
#  batch_normalization_134 (Ba  (None, 128, 128, 80)     320
#  tchNormalization)
#
#  leaky_re_lu_11 (LeakyReLU)  (None, 128, 128, 80)      0
#
#  conv2d_147 (Conv2D)         (None, 64, 64, 80)        57680
#
#  batch_normalization_135 (Ba  (None, 64, 64, 80)       320
#  tchNormalization)
#
#  leaky_re_lu_12 (LeakyReLU)  (None, 64, 64, 80)        0
#
#  conv2d_148 (Conv2D)         (None, 64, 64, 160)       115360
#
#  batch_normalization_136 (Ba  (None, 64, 64, 160)      640
#  tchNormalization)
#
#  leaky_re_lu_13 (LeakyReLU)  (None, 64, 64, 160)       0
#
#  conv2d_149 (Conv2D)         (None, 32, 32, 160)       230560
#
#  batch_normalization_137 (Ba  (None, 32, 32, 160)      640
#  tchNormalization)
#
#  leaky_re_lu_14 (LeakyReLU)  (None, 32, 32, 160)       0
#
#  conv2d_150 (Conv2D)         (None, 32, 32, 320)       461120
#
#  batch_normalization_138 (Ba  (None, 32, 32, 320)      1280
#  tchNormalization)
#
#  leaky_re_lu_15 (LeakyReLU)  (None, 32, 32, 320)       0
#
#  conv2d_151 (Conv2D)         (None, 16, 16, 320)       921920
#
#  batch_normalization_139 (Ba  (None, 16, 16, 320)      1280
#  tchNormalization)
#
#  leaky_re_lu_16 (LeakyReLU)  (None, 16, 16, 320)       0
#
#  flatten_1 (Flatten)         (None, 81920)             0
#
#  dense_2 (Dense)             (None, 640)               52429440
#
#  leaky_re_lu_17 (LeakyReLU)  (None, 640)               0
#
#  dense_3 (Dense)             (None, 1)                 641
#
# =================================================================
# Total params: 54,265,801
# Trainable params: 54,263,481
# Non-trainable params: 2,320
# _________________________________________________________________
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [11], in <cell line: 10>()
#       7 discriminator.compile(loss="binary_crossentropy",optimizer="adam",metrics=['accuracy'])
#       8 discriminator.summary()
# ---> 10 vgg = build_vgg((256,256,3))
#      11 print(vgg.summary())
#      12 vgg.trainable = False
#
# Input In [6], in build_vgg(hr_shape)
#       3 def build_vgg(hr_shape):
# ----> 5     vgg = VGG19(weights="imagenet",include_top=False, input_shape=hr_shape)
#       7     return Model(inputs=vgg.inputs, outputs=vgg.layers[10].output)
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\keras\applications\vgg19.py:256, in VGG19(include_top, weights, input_tensor, input_shape, pooling, classes, classifier_activation)
#     249     else:
#     250         weights_path = data_utils.get_file(
#     251             "vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5",
#     252             WEIGHTS_PATH_NO_TOP,
#     253             cache_subdir="models",
#     254             file_hash="253f8cb515780f3b799900260a226db6",
#     255         )
# --> 256     model.load_weights(weights_path)
#     257 elif weights is not None:
#     258     model.load_weights(weights)
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\miniconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:2920, in Model.load_weights(self, filepath, by_name, skip_mismatch, options)
#    2918 status = None
#    2919 if h5py is None:
# -> 2920     raise ImportError(
#    2921         "`load_weights` requires h5py package when loading weights "
#    2922         "from HDF5. Try installing h5py."
#    2923     )
#    2924 if not self._is_graph_network and not self.built:
#    2925     raise ValueError(
#    2926         "Unable to load weights saved in HDF5 format into a "
#    2927         "subclassed Model which has not created its variables yet. "
#    2928         "Call the Model first, then load the weights."
#    2929     )
#
# ImportError: `load_weights` requires h5py package when loading weights from HDF5. Try installing h5py.

# %%
# TRAINING

# Custom batch of data
batch_size = 1
train_lr_batches = []
train_hr_batches = []

for it in range(int(len(hr_train)/batch_size)):
    start_idx = it * batch_size
    end_idx = start_idx + batch_size
    train_hr_batches.append(hr_train[start_idx:end_idx])
    train_lr_batches.append(lr_train[start_idx:end_idx])

epochs = 30


for e in range(epochs):
    fake_label = np.zeros((batch_size,1))
    real_label = np.ones((batch_size,1))

    g_losses = []
    d_losses = []

    for b in tqdm(range(len(train_hr_batches))):
      #......
        lr_image_urls = train_lr_batches[b]
        lr_images = cv2.imread("".join(lr_image_urls))
        lr_images = np.array(lr_images)
        lr_images = cv2.cvtColor(lr_images, cv2.COLOR_BGR2RGB)
        lr_images = lr_images/255

        hr_image_urls = train_hr_batches[b]
        hr_images = cv2.imread("".join(hr_image_urls))
        hr_images = np.array(hr_images)
        hr_images = cv2.cvtColor(hr_images, cv2.COLOR_BGR2RGB)
        hr_images = hr_images/255

        lr_images = np.expand_dims(lr_images, axis=0)
        hr_images = np.expand_dims(hr_images,axis=0)
#...
        fake_imgs = generator.predict_on_batch(lr_images)

        discriminator.trainable = True
        d_losses_gen = discriminator.train_on_batch(fake_imgs,fake_label)
        d_losses_real = discriminator.train_on_batch(hr_images,real_label)

        discriminator.trainable = False

        d_loss = 0.5 + np.add(d_losses_gen, d_losses_real)
        image_features = vgg.predict(hr_images)

        g_loss, _, _ = gan_model.train_on_batch([lr_images, hr_images],[real_label, image_features])

        d_losses.append(d_loss)
        g_losses.append(g_loss)

    g_losses = np.array(g_losses)
    d_losses = np.array(d_losses)

    g_loss = np.sum(g_losses, axis=0)/ len(g_losses)
    d_loss = np.sum(d_losses,axis=0) / len(d_losses)

    print("epoch:", e+1, "g_loss:", g_loss, "d_loss:", d_loss)

    generator.save("gen_e_"+str(e+1)+" "+str(g_loss)+" "+str(n)+" "+str(d_loss)+".h5")

# %%
#Imageflow
# filepath = "Treeweights-{epoch:82d}-{val_accuracy:.2f}.hdf5"
# checkpoint = ModelCheckpoint(filepath,monitor='val_accuracy',verbose=1,save_best_only=True,mode='max')
# callbacks_list = [checkpoint]
#
# aug = ImageDataGenerator(rotation_range=20, zoom_range=0.2,
#      rescale=1./255,
#     width_shift_range=0.1,
#       height_shift_range=0.1,
#   	horizontal_flip=True,
#      brightness_range=[0.5,2.5], fill_mode="nearest")
#
# aug_val = ImageDataGenerator(rescale=1./255)

#Fit_model
# vgghist=vggmodel.fit_generator(aug.flow(x_train, y_train, batch_size=64),
#                                  epochs=50,
#                                  validation_data=aug.flow(x_test,y_test,
#                                  batch_size=64),
#                                  callbacks=callbacks_list)


#Load weights
# generator = create_gen(lr_ip, num_res_block=16)
# generator.summary()
#
# discriminator = create_disc(hr_ip)
# discriminator.compile(loss="binary_crossentopy",optimizer="adam",metrics=['accuracy'])
# discriminator.summary()
#
# vgg = build_vgg((128,128,3))
# print(vgg.summary())
# vgg.trainable = False
#
# gan_model = create_comb(generator,discriminator,vgg,lr_ip,hr_ip)
# gan_model.load_weights()
